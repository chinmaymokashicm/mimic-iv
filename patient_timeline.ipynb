# %%
from func_code.query import Query
import matplotlib.pyplot as plt
import pandas as pd
import json, os, sys
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
q = Query()

# %%
subject_id = 10015860

# %%
q.set_subject_id(subject_id)

# %%
q.get_patient_info()
# Out:
# {'gender': 'M',
#  'anchor_age': 53,
#  'anchor_year': 2186,
#  'anchor_year_group': '2011 - 2013',
#  'dod': nan}

# %%
q.get_events()
# Out:
# {'hadm_ids': [25085565,
#   28236161,
#   27670224,
#   28613200,
#   20854119,
#   20790339,
#   22607171,
#   22413744,
#   24698912,
#   25103777,
#   26352758,
#   22416954,
#   28196804],
#  'hadm': {25085565: [{'event': 'transfer',
#     'subject_id': 10015860,
#     'hadm_id': 25085565,
#     'transfer_id': 35958096,
#     'eventtype': 'ED',
#     'careunit': 'Emergency Department',
#     'intime': '2186-09-15 12:56:00',
#     'outtime': '2186-09-15 17:15:00'},
#    {'event': 'admission',
#     'admittime': '2186-09-15 16:12:00',
#     'dischtime': '2186-09-29 18:05:00',
#     'deathtime': NaT,
#     'admission_type': 'EW EMER.',
#     'admit_provider_id': 'P56SP9',
#     'admission_location': 'EMERGENCY ROOM',
#     'discharge_location': 'REHAB',
#     'insurance': 'Other',
#     'language': 'ENGLISH',
#     'marital_status': 'SINGLE',
#     'race': 'WHITE',
#     'edregtime': '2186-09-15 12:56:00',
#     'edouttime': '2186-09-15 17:15:00',
#     'hospital_expire_flag': 0},
# ...

# %%
q.get_admission_info("hosp", "labevents", 25085565)
# Out:
# [{'labevent_id': 196351,
#   'subject_id': 10015860,
#   'hadm_id': 25085565,
#   'specimen_id': 44349288,
#   'itemid': 51301,
#   'order_provider_id': nan,
#   'charttime': '2186-09-26 06:00:00',
#   'storetime': '2186-09-26 06:25:00',
#   'value': '11.4',
#   'valuenum': 11.4,
#   'valueuom': 'K/uL',
#   'ref_range_lower': 4.0,
#   'ref_range_upper': 11.0,
#   'flag': 'abnormal',
#   'priority': 'STAT',
#   'comments': nan},
#  {'labevent_id': 196346,
#   'subject_id': 10015860,
#   'hadm_id': 25085565,
#   'specimen_id': 44349288,
#   'itemid': 51249,
#   'order_provider_id': nan,
#   'charttime': '2186-09-26 06:00:00',
#   'storetime': '2186-09-26 06:25:00',
#   'value': '34.4',
#   'valuenum': 34.4,
#   'valueuom': '%',
#   'ref_range_lower': 31.0,
#   'ref_range_upper': 35.0,
#   'flag': nan,
#   'priority': 'STAT',
#   'comments': nan},
#  {'labevent_id': 196344,
#   'subject_id': 10015860,
#   'hadm_id': 25085565,
#   'specimen_id': 44349288,
#   'itemid': 51222,
# ...

# %%
q.dict_patient_results["hosp"]["hcpcsevents"]
# Out:
#    subject_id   hadm_id   chartdate hcpcs_cd  seq_num
# 50   10015860  27670224  2187-12-14    99219        1  \
# 51   10015860  22416954  2193-05-03    99219        1
# 52   10015860  22607171  2190-05-15    99219        1
#
#                 short_description
# 50  Hospital observation services
# 51  Hospital observation services
# 52  Hospital observation services
